# %% [markdown]
# #### you should download ollama in below link
#
# https://ollama.com/download

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %% [markdown]
# ##### you should download the model using below command
# ollama run gemma2:2b

# %%
embeddings = OllamaEmbeddings(
    model="gemma2:2b"
)
# Out:
# C:\Users\Bhavesh Kilaru\AppData\Local\Temp\ipykernel_12324\2536262513.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(

# %%
r1 = embeddings.embed_documents(
    [
        "alpha is first character of greek alphabet",
        "Beta is first character of greek alphabet",
    ]
)

# %%
len(r1[0])
# Out:
# 2304

# %%
r1[1]
# Out:
# [-0.15761126577854156,
#  -0.1595592200756073,
#  -1.2040337324142456,
#  0.5357109904289246,
#  0.8059802651405334,
#  1.3210922479629517,
#  1.0341249704360962,
#  0.5613769888877869,
#  -0.4522651731967926,
#  1.451988935470581,
#  -2.2980072498321533,
#  -1.0877071619033813,
#  -0.10825032740831375,
#  -1.0308440923690796,
#  -0.025535041466355324,
#  -0.3269193768501282,
#  -3.318782329559326,
#  -1.5070496797561646,
#  -4.283514976501465,
#  -0.4263567328453064,
#  1.5004156827926636,
#  1.0837351083755493,
#  -1.5958154201507568,
#  -1.4437869787216187,
#  2.9487686157226562,
#  -0.9440663456916809,
#  0.9238097071647644,
#  0.9826626181602478,
#  -0.5021731853485107,
#  0.8670462369918823,
#  -1.4866398572921753,
#  1.1812914609909058,
#  -1.4338326454162598,
#  -1.476427674293518,
#  0.4638981819152832,
#  1.6488112211227417,
#  -0.8533388376235962,
#  0.7922708988189697,
#  0.4283658266067505,
#  -1.9715533256530762,
#  -0.37029334902763367,
#  2.138821601867676,
# ...

# %%
embeddings.embed_query("what is the second letter of greek alphabet ")
# Out:
# [-0.1598425656557083,
#  0.20707811415195465,
#  -3.503516674041748,
#  0.6980472207069397,
#  1.479495882987976,
#  0.7114256620407104,
#  0.7842528223991394,
#  0.051382310688495636,
#  0.2575475573539734,
#  1.8161413669586182,
#  -2.678434133529663,
#  0.17040282487869263,
#  -0.5038217902183533,
#  -1.8668972253799438,
#  0.5683255195617676,
#  0.7583165168762207,
#  -9.74313735961914,
#  0.5980338454246521,
#  -2.9852497577667236,
#  0.011235684156417847,
#  2.0087974071502686,
#  1.4454731941223145,
#  -0.3639308214187622,
#  1.8067976236343384,
#  1.8027757406234741,
#  -1.3348286151885986,
#  2.259308338165283,
#  -2.8621695041656494,
#  -0.2349909096956253,
#  -0.2297877073287964,
#  -0.8126278519630432,
#  1.1638342142105103,
#  -3.0269265174865723,
#  -1.0383903980255127,
#  -0.2206258773803711,
#  3.24769926071167,
#  -0.9417951107025146,
#  -0.5781198740005493,
#  -0.07647576928138733,
#  0.3278685212135315,
#  -0.9449988007545471,
#  1.8796417713165283,
# ...

# %% [markdown]
# #### check different ollama embedding models in below link
# https://ollama.com/blog/embedding-models
